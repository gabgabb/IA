# %%
import numpy as np
x = np.random.rand(500) * 5
print(f'first few values {x[:5]}')
print(f'minimum hours studied {x.min()}, maximum hours studied {x.max()}')
print(f'mean hours studied {x.mean()}')
print(f'standard deviation of hours studied {x.std()}')
# Out:
# first few values [1.09143701 2.86002712 2.09891079 2.81421349 2.50567838]
# minimum hours studied 0.0007390510672172779, maximum hours studied 4.999399887318578
# mean hours studied 2.437922416059041
# standard deviation of hours studied 1.4100624358719756

# %%
y = ((3 * x + 3) + np.random.randn(len(x)) * 2.5).clip(0, 20)
print(f'minimum grade {y.min()}')
print(f'maximum grade {y.max()}')
print(f'mean grade {y.mean()}')
print(f'standard deviation of the grades {y.std()}')
# Out:
# minimum grade 0.0
# maximum grade 20.0
# mean grade 10.37165708839785
# standard deviation of the grades 4.858481050076547

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8, 8))
plt.xlabel('Number of hours studied')
plt.ylabel('Exam grade')
plt.scatter(x, y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (450,) (50,) (450,) (50,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
print(x_train.shape, x_test.shape)
x_train = x_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
print(x_train.shape, x_test.shape)
# Out:
# (450,) (50,)
# (450, 1) (50, 1)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
hours_studied = np.array([1, 2, 3]).reshape(-1, 1)
print(f'input shape: {hours_studied.shape}')
y_pred = model.predict(hours_studied)
print(y_pred)
# Out:
# input shape: (3, 1)
# [ 5.93529313  8.8592337  11.78317428]

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
animals = pd.Series(['dog', 'cat', 'dog', 'dog', 'cat'])
label_encoder = LabelEncoder()
label_encoder.fit(animals.unique())
encoded_animals = label_encoder.transform(animals)
print('Classes', label_encoder.classes_)
print('Original series\n', animals)
print('Encoded series', encoded_animals)
# Out:
# Classes ['cat' 'dog']
# Original series
#  0    dog
# 1    cat
# 2    dog
# 3    dog
# 4    cat
# dtype: object
# Encoded series [1 0 1 1 0]

# %%
smoker = df.smoker
label_encoder_smoker = LabelEncoder
label_encoder_smoker.fit(smoker)
encoded_smoker = label_encoder_smoker.transform(smoker)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 smoker = df.smoker
#       2 label_encoder_smoker = LabelEncoder
# ----> 3 label_encoder_smoker.fit(smoker)
#       4 encoded_smoker = label_encoder_smoker.transform(smoker)
#
# TypeError: LabelEncoder.fit() missing 1 required positional argument: 'y'

# %%
print(encoded_smoker)
# Out:
# [1 0 0 ... 0 0 1]

# %%
sex = df.sex
label_encoder_sex = LabelEncoder
label_encoder_sex.fit(sex)
encoded_sex = label_encoder_sex.transform(sex)

# %%
print(encoded_sex)
# Out:
# [0 1 1 ... 0 0 0]

# %%
df.smoker = encoded_smoker

# %%
df.sex = encoded_sex
print(df)
# Out:
#       age  sex     bmi  children  smoker      charges  region_northeast  \
# 0      19    0  27.900         0       1  16884.92400                 0
# 1      18    1  33.770         1       0   1725.55230                 0
# 2      28    1  33.000         3       0   4449.46200                 0
# 3      33    1  22.705         0       0  21984.47061                 0
# 4      32    1  28.880         0       0   3866.85520                 0
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830                 0
# 1334   18    0  31.920         0       0   2205.98080                 1
# 1335   18    0  36.850         0       0   1629.83350                 0
# 1336   21    0  25.800         0       0   2007.94500                 0
# 1337   61    0  29.070         0       1  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.children.hist(bins = 5)
plt.xlabel('Number of children')
plt.ylabel('Number of persons')
# Out:
# Text(0, 0.5, 'Number of persons')

# %%
df = pd.read_csv('insurance.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df = pd.read_csv('insurance.csv')
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
smoker = df.smoker
encoder_smoker = LabelEncoder()
encoder_smoker.fit(smoker)
encoded_smoker = encoder_smoker.transform(smoker)

# %%
print(df)
# Out:
#       age  sex     bmi  children  smoker      charges  region_northeast  \
# 0      19    0  27.900         0       1  16884.92400                 0
# 1      18    1  33.770         1       0   1725.55230                 0
# 2      28    1  33.000         3       0   4449.46200                 0
# 3      33    1  22.705         0       0  21984.47061                 0
# 4      32    1  28.880         0       0   3866.85520                 0
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    1  30.970         3       0  10600.54830                 0
# 1334   18    0  31.920         0       0   2205.98080                 1
# 1335   18    0  36.850         0       0   1629.83350                 0
# 1336   21    0  25.800         0       0   2007.94500                 0
# 1337   61    0  29.070         0       1  29141.36030                 0
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
print(df.sex.value_counts())
# Out:
# 1    676
# 0    662
# Name: sex, dtype: int64

# %%
for row in df :
    if row.__contains__('region') :
        print('Moyenne de la région ' + row.replace('region_','') + ' : ' + str("%.2f" % ( df.loc[df[row], 'charges'].mean())))
# Out:
# Moyenne de la région northeast : 13214.04
# Moyenne de la région northwest : 13202.71
# Moyenne de la région southeast : 12760.85
# Moyenne de la région southwest : 13202.71

# %%
plt.figure(figsize = (10, 7))
for smoker_id, df_smoker in df.groupby('smoker'):
    label = label_encoder.classes_[smoker_id]
    df_smoker.charges.hist(bins = 40, label = label, alpha = .5)
plt.title('Charges by smoker')
plt.xlabel('Charges')
plt.ylabel('Smoker')
plt.legend()

# %%
df = pd.read_csv('insurance.csv')
q1 = 0
q2 = 0
q3 = 0
for age in df.age :
    if age < df.age.quantile(1/3):
        q1+=1
    elif age < df.age.quantile(2/3):
        q2+=1
    else :
        q3+=1
print(q1, q2, q3)


plt.figure(figsize = (10, 7))
for smoker_id, df_smoker in df.groupby('smoker'):
    label = label_encoder.classes_[smoker_id]
    df_smoker.charges.hist(bins = 40, label = label, alpha = .5)
plt.title('Charges by smoker')
plt.xlabel('Charges')
plt.ylabel('Smoker')
plt.legend()
# Out:
# 444 423 471
